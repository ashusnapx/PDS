# %% [markdown]
# Q1. Load the "titanic" dataset using the load_dataset function of seaborn. Use Plotly express to plot a
# scatter plot for age and fare columns in the titanic dataset.

# %%
pip install zipline
# Out:
# Collecting zipline
#   Downloading zipline-1.4.1.tar.gz (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 4.0 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pip>=7.1.0 in /Users/ashu/.pyenv/versions/3.10.2/lib/python3.10/site-packages (from zipline) (23.1.2)
# Requirement already satisfied: setuptools>18.0 in /Users/ashu/.pyenv/versions/3.10.2/lib/python3.10/site-packages (from zipline) (58.1.0)
# Collecting Logbook>=0.12.5 (from zipline)
#   Downloading Logbook-1.5.3.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.8/85.8 kB 3.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: click>=4.0.0 in /Users/ashu/.pyenv/versions/3.10.2/lib/python3.10/site-packages (from zipline) (8.1.3)
# Requirement already satisfied: six>=1.10.0 in /Users/ashu/.pyenv/versions/3.10.2/lib/python3.10/site-packages (from zipline) (1.16.0)
# Collecting python-interface>=1.5.3 (from zipline)
#   Downloading python-interface-1.6.1.tar.gz (19 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting multipledispatch>=0.6.0 (from zipline)
#   Downloading multipledispatch-0.6.0-py3-none-any.whl (11 kB)
# Collecting toolz>=0.8.2 (from zipline)
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.11.3 in /Users/ashu/.pyenv/versions/3.10.2/lib/python3.10/site-packages (from zipline) (1.24.2)
# Collecting pandas<=0.22,>=0.18.1 (from zipline)
#   Downloading pandas-0.22.0.tar.gz (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 3.7 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [773 lines of output]
#       Ignoring numpy: markers 'python_version == "3.5"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.6"' don't match your environment
#       Collecting wheel
#         Using cached wheel-0.40.0-py3-none-any.whl (64 kB)
#       Collecting setuptools
#         Using cached setuptools-67.8.0-py3-none-any.whl (1.1 MB)
#       Collecting Cython
#         Using cached Cython-0.29.35-py2.py3-none-any.whl (988 kB)
#       Collecting numpy==1.13.1
#         Downloading numpy-1.13.1.zip (5.0 MB)
#                                                     0.0/5.0 MB ? eta -:--:--
#                                                     0.0/5.0 MB 2.3 MB/s eta 0:00:03
#            ╸                                        0.1/5.0 MB 1.6 MB/s eta 0:00:04
#            ━━                                       0.3/5.0 MB 2.6 MB/s eta 0:00:02
#            ━━━━╸                                    0.6/5.0 MB 3.7 MB/s eta 0:00:02
#            ━━━━━━╸                                  0.9/5.0 MB 4.5 MB/s eta 0:00:01
#            ━━━━━━━━                                 1.0/5.0 MB 4.4 MB/s eta 0:00:01
#            ━━━━━━━━━                                1.2/5.0 MB 4.3 MB/s eta 0:00:01
#            ━━━━━━━━━                                1.2/5.0 MB 4.3 MB/s eta 0:00:01
#            ━━━━━━━━━                                1.2/5.0 MB 4.3 MB/s eta 0:00:01
#            ━━━━━━━━━                                1.2/5.0 MB 4.3 MB/s eta 0:00:01
#            ━━━━━━━━━╸                               1.2/5.0 MB 3.0 MB/s eta 0:00:02
#            ━━━━━━━━━╸                               1.2/5.0 MB 3.0 MB/s eta 0:00:02
#            ━━━━━━━━━━━━━━━━╸                        2.1/5.0 MB 4.1 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━╸                       2.2/5.0 MB 4.1 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━                      2.4/5.0 MB 4.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━                     2.5/5.0 MB 4.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━                    2.7/5.0 MB 4.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━                    2.7/5.0 MB 4.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━                    2.7/5.0 MB 4.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━                    2.7/5.0 MB 4.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━╸                3.1/5.0 MB 3.7 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━╸             3.5/5.0 MB 4.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸            3.6/5.0 MB 4.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━           3.8/5.0 MB 4.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━          3.9/5.0 MB 4.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━         4.1/5.0 MB 4.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸       4.2/5.0 MB 4.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸      4.4/5.0 MB 4.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━     4.5/5.0 MB 3.9 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━    4.7/5.0 MB 3.9 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   4.8/5.0 MB 3.9 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 5.0/5.0 MB 3.9 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 5.0/5.0 MB 3.9 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 3.8 MB/s eta 0:00:00
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'done'
#         Preparing metadata (pyproject.toml): started
#         Preparing metadata (pyproject.toml): finished with status 'done'
#       Building wheels for collected packages: numpy
#         Building wheel for numpy (pyproject.toml): started
#         Building wheel for numpy (pyproject.toml): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × Building wheel for numpy (pyproject.toml) did not run successfully.
#         │ exit code: 1
#         ╰─> [708 lines of output]
#             Running from numpy source directory.
#             blas_opt_info:
#             blas_mkl_info:
#               libraries mkl_rt not found in ['/Users/ashu/.pyenv/versions/3.10.2/lib', '/usr/local/lib', '/usr/lib']
#               NOT AVAILABLE
#
#             blis_info:
#               libraries blis not found in ['/Users/ashu/.pyenv/versions/3.10.2/lib', '/usr/local/lib', '/usr/lib']
#               NOT AVAILABLE
#
#             openblas_info:
#               libraries openblas not found in ['/Users/ashu/.pyenv/versions/3.10.2/lib', '/usr/local/lib', '/usr/lib']
#               NOT AVAILABLE
#
#             atlas_3_10_blas_threads_info:
#             Setting PTATLAS=ATLAS
#               libraries tatlas not found in ['/Users/ashu/.pyenv/versions/3.10.2/lib', '/usr/local/lib', '/usr/lib']
#               NOT AVAILABLE
#
#             atlas_3_10_blas_info:
#               libraries satlas not found in ['/Users/ashu/.pyenv/versions/3.10.2/lib', '/usr/local/lib', '/usr/lib']
#               NOT AVAILABLE
#
#             atlas_blas_threads_info:
#             Setting PTATLAS=ATLAS
#               libraries ptf77blas,ptcblas,atlas not found in ['/Users/ashu/.pyenv/versions/3.10.2/lib', '/usr/local/lib', '/usr/lib']
#               NOT AVAILABLE
#
#             atlas_blas_info:
#               libraries f77blas,cblas,atlas not found in ['/Users/ashu/.pyenv/versions/3.10.2/lib', '/usr/local/lib', '/usr/lib']
#               NOT AVAILABLE
#
#               FOUND:
#                 extra_compile_args = ['-faltivec', '-I/System/Library/Frameworks/vecLib.framework/Headers']
#                 extra_link_args = ['-Wl,-framework', '-Wl,Accelerate']
#                 define_macros = [('NO_ATLAS_INFO', 3), ('HAVE_CBLAS', None)]
#
#             /bin/sh: svnversion: command not found
#             non-existing path in 'numpy/distutils': 'site.cfg'
#             /bin/sh: svnversion: command not found
#             F2PY Version 2
#             lapack_opt_info:
#             lapack_mkl_info:
#               libraries mkl_rt not found in ['/Users/ashu/.pyenv/versions/3.10.2/lib', '/usr/local/lib', '/usr/lib']
#               NOT AVAILABLE
#
#             openblas_lapack_info:
#               libraries openblas not found in ['/Users/ashu/.pyenv/versions/3.10.2/lib', '/usr/local/lib', '/usr/lib']
#               NOT AVAILABLE
#
#             atlas_3_10_threads_info:
#             Setting PTATLAS=ATLAS
#               libraries tatlas,tatlas not found in /Users/ashu/.pyenv/versions/3.10.2/lib
#               libraries lapack_atlas not found in /Users/ashu/.pyenv/versions/3.10.2/lib
#               libraries tatlas,tatlas not found in /usr/local/lib
#               libraries lapack_atlas not found in /usr/local/lib
#               libraries tatlas,tatlas not found in /usr/lib
#               libraries lapack_atlas not found in /usr/lib
#             <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#               NOT AVAILABLE
#
#             atlas_3_10_info:
#               libraries satlas,satlas not found in /Users/ashu/.pyenv/versions/3.10.2/lib
#               libraries lapack_atlas not found in /Users/ashu/.pyenv/versions/3.10.2/lib
#               libraries satlas,satlas not found in /usr/local/lib
#               libraries lapack_atlas not found in /usr/local/lib
#               libraries satlas,satlas not found in /usr/lib
#               libraries lapack_atlas not found in /usr/lib
#             <class 'numpy.distutils.system_info.atlas_3_10_info'>
#               NOT AVAILABLE
#
#             atlas_threads_info:
#             Setting PTATLAS=ATLAS
#               libraries ptf77blas,ptcblas,atlas not found in /Users/ashu/.pyenv/versions/3.10.2/lib
#               libraries lapack_atlas not found in /Users/ashu/.pyenv/versions/3.10.2/lib
#               libraries ptf77blas,ptcblas,atlas not found in /usr/local/lib
#               libraries lapack_atlas not found in /usr/local/lib
#               libraries ptf77blas,ptcblas,atlas not found in /usr/lib
#               libraries lapack_atlas not found in /usr/lib
#             <class 'numpy.distutils.system_info.atlas_threads_info'>
#               NOT AVAILABLE
#
#             atlas_info:
#               libraries f77blas,cblas,atlas not found in /Users/ashu/.pyenv/versions/3.10.2/lib
#               libraries lapack_atlas not found in /Users/ashu/.pyenv/versions/3.10.2/lib
#               libraries f77blas,cblas,atlas not found in /usr/local/lib
#               libraries lapack_atlas not found in /usr/local/lib
#               libraries f77blas,cblas,atlas not found in /usr/lib
#               libraries lapack_atlas not found in /usr/lib
#             <class 'numpy.distutils.system_info.atlas_info'>
#               NOT AVAILABLE
#
#               FOUND:
#                 extra_compile_args = ['-faltivec']
#                 extra_link_args = ['-Wl,-framework', '-Wl,Accelerate']
#                 define_macros = [('NO_ATLAS_INFO', 3), ('HAVE_CBLAS', None)]
#
#             /private/var/folders/y4/6zfff_pj0h39ylj3s39306rc0000gn/T/pip-build-env-gv7aycne/overlay/lib/python3.10/site-packages/setuptools/_distutils/dist.py:265: UserWarning: Unknown distribution option: 'define_macros'
#               warnings.warn(msg)
#             running bdist_wheel
#             running build
#             running config_cc
#             unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#             running config_fc
#             unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#             running build_src
#             build_src
#             building py_modules sources
#             building library "npymath" sources
#             customize Gnu95FCompiler
#             Found executable /opt/homebrew/bin/gfortran
#             customize Gnu95FCompiler
#             customize Gnu95FCompiler using config
#             C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include
#
#             compile options: '-Inumpy/core/src/private -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/ashu/.pyenv/versions/3.10.2/include/python3.10 -c'
#             clang: _configtest.c
#             clang _configtest.o -o _configtest
#             success!
#             removing: _configtest.c _configtest.o _configtest
#             C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include
#
#             compile options: '-Inumpy/core/src/private -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/ashu/.pyenv/versions/3.10.2/include/python3.10 -c'
#             clang: _configtest.c
#             _configtest.c:1:5: warning: incompatible redeclaration of library function 'exp' [-Wincompatible-library-redeclaration]
#             int exp (void);
#                 ^
#             _configtest.c:1:5: note: 'exp' is a builtin with type 'double (double)'
#             1 warning generated.
#             clang _configtest.o -o _configtest
#             success!
#             removing: _configtest.c _configtest.o _configtest
#               adding 'build/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath' to include_dirs.
#             None - nothing done with h_files = ['build/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath/npy_math_internal.h']
#             building library "npysort" sources
#               adding 'build/src.macosx-12.3-arm64-3.1/numpy/core/src/private' to include_dirs.
#             None - nothing done with h_files = ['build/src.macosx-12.3-arm64-3.1/numpy/core/src/private/npy_partition.h', 'build/src.macosx-12.3-arm64-3.1/numpy/core/src/private/npy_binsearch.h']
#             building extension "numpy.core._dummy" sources
#               adding 'build/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy/config.h' to sources.
#               adding 'build/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy/_numpyconfig.h' to sources.
#             executing numpy/core/code_generators/generate_numpy_api.py
#               adding 'build/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy/__multiarray_api.h' to sources.
#             numpy.core - nothing done with h_files = ['build/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy/config.h', 'build/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy/_numpyconfig.h', 'build/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy/__multiarray_api.h']
#             building extension "numpy.core.multiarray" sources
#               adding 'build/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy/config.h' to sources.
#               adding 'build/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy/_numpyconfig.h' to sources.
#             executing numpy/core/code_generators/generate_numpy_api.py
#               adding 'build/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy/__multiarray_api.h' to sources.
#               adding 'build/src.macosx-12.3-arm64-3.1/numpy/core/src/private' to include_dirs.
#             numpy.core - nothing done with h_files = ['build/src.macosx-12.3-arm64-3.1/numpy/core/src/private/templ_common.h', 'build/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy/config.h', 'build/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy/_numpyconfig.h', 'build/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy/__multiarray_api.h']
#             building extension "numpy.core.umath" sources
#               adding 'build/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy/config.h' to sources.
#               adding 'build/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy/_numpyconfig.h' to sources.
#             executing numpy/core/code_generators/generate_ufunc_api.py
#               adding 'build/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy/__ufunc_api.h' to sources.
#               adding 'build/src.macosx-12.3-arm64-3.1/numpy/core/src/umath' to include_dirs.
#             numpy.core - nothing done with h_files = ['build/src.macosx-12.3-arm64-3.1/numpy/core/src/umath/funcs.inc', 'build/src.macosx-12.3-arm64-3.1/numpy/core/src/umath/simd.inc', 'build/src.macosx-12.3-arm64-3.1/numpy/core/src/umath/loops.h', 'build/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy/config.h', 'build/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy/_numpyconfig.h', 'build/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy/__ufunc_api.h']
#             building extension "numpy.core.umath_tests" sources
#             building extension "numpy.core.test_rational" sources
#             building extension "numpy.core.struct_ufunc_test" sources
#             building extension "numpy.core.multiarray_tests" sources
#             building extension "numpy.core.operand_flag_tests" sources
#             building extension "numpy.fft.fftpack_lite" sources
#             building extension "numpy.linalg.lapack_lite" sources
#               adding 'numpy/linalg/lapack_lite/python_xerbla.c' to sources.
#             building extension "numpy.linalg._umath_linalg" sources
#               adding 'numpy/linalg/lapack_lite/python_xerbla.c' to sources.
#             building extension "numpy.random.mtrand" sources
#             building data_files sources
#             build_src: building npy-pkg config files
#             running build_py
#             creating build/lib.macosx-12.3-arm64-cpython-310
#             creating build/lib.macosx-12.3-arm64-cpython-310/numpy
#             copying numpy/version.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy
#             copying numpy/add_newdocs.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy
#             copying numpy/_globals.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy
#             copying numpy/__init__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy
#             copying numpy/dual.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy
#             copying numpy/_distributor_init.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy
#             copying numpy/setup.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy
#             copying numpy/ctypeslib.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy
#             copying numpy/_import_tools.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy
#             copying numpy/matlib.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy
#             copying build/src.macosx-12.3-arm64-3.1/numpy/__config__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy
#             creating build/lib.macosx-12.3-arm64-cpython-310/numpy/compat
#             copying numpy/compat/py3k.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/compat
#             copying numpy/compat/__init__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/compat
#             copying numpy/compat/setup.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/compat
#             copying numpy/compat/_inspect.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/compat
#             creating build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/fromnumeric.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/_methods.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/_internal.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/records.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/__init__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/setup_common.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/memmap.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/getlimits.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/defchararray.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/shape_base.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/machar.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/setup.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/numeric.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/function_base.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/einsumfunc.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/info.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/numerictypes.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/cversions.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/arrayprint.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             copying numpy/core/code_generators/generate_numpy_api.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/core
#             creating build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/unixccompiler.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/numpy_distribution.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/conv_template.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/cpuinfo.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/ccompiler.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/msvc9compiler.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/npy_pkg_config.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/compat.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/misc_util.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/log.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/line_endings.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/lib2def.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/pathccompiler.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/system_info.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/__init__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/core.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/__version__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/exec_command.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/from_template.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/mingw32ccompiler.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/setup.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/extension.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/msvccompiler.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/environment.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/intelccompiler.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying numpy/distutils/info.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             copying build/src.macosx-12.3-arm64-3.1/numpy/distutils/__config__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils
#             creating build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             copying numpy/distutils/command/build.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             copying numpy/distutils/command/config_compiler.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             copying numpy/distutils/command/build_ext.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             copying numpy/distutils/command/config.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             copying numpy/distutils/command/install_headers.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             copying numpy/distutils/command/build_py.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             copying numpy/distutils/command/build_src.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             copying numpy/distutils/command/__init__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             copying numpy/distutils/command/sdist.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             copying numpy/distutils/command/build_scripts.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             copying numpy/distutils/command/bdist_rpm.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             copying numpy/distutils/command/install_clib.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             copying numpy/distutils/command/build_clib.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             copying numpy/distutils/command/autodist.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             copying numpy/distutils/command/egg_info.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             copying numpy/distutils/command/install.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             copying numpy/distutils/command/develop.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             copying numpy/distutils/command/install_data.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/command
#             creating build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/fcompiler
#             copying numpy/distutils/fcompiler/gnu.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/fcompiler
#             copying numpy/distutils/fcompiler/compaq.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/fcompiler
#             copying numpy/distutils/fcompiler/intel.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/fcompiler
#             copying numpy/distutils/fcompiler/none.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/fcompiler
#             copying numpy/distutils/fcompiler/nag.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/fcompiler
#             copying numpy/distutils/fcompiler/pg.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/fcompiler
#             copying numpy/distutils/fcompiler/ibm.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/fcompiler
#             copying numpy/distutils/fcompiler/sun.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/fcompiler
#             copying numpy/distutils/fcompiler/lahey.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/fcompiler
#             copying numpy/distutils/fcompiler/__init__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/fcompiler
#             copying numpy/distutils/fcompiler/g95.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/fcompiler
#             copying numpy/distutils/fcompiler/mips.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/fcompiler
#             copying numpy/distutils/fcompiler/hpux.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/fcompiler
#             copying numpy/distutils/fcompiler/pathf95.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/fcompiler
#             copying numpy/distutils/fcompiler/absoft.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/fcompiler
#             copying numpy/distutils/fcompiler/vast.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/distutils/fcompiler
#             creating build/lib.macosx-12.3-arm64-cpython-310/numpy/doc
#             copying numpy/doc/misc.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/doc
#             copying numpy/doc/internals.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/doc
#             copying numpy/doc/creation.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/doc
#             copying numpy/doc/constants.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/doc
#             copying numpy/doc/ufuncs.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/doc
#             copying numpy/doc/__init__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/doc
#             copying numpy/doc/broadcasting.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/doc
#             copying numpy/doc/basics.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/doc
#             copying numpy/doc/subclassing.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/doc
#             copying numpy/doc/indexing.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/doc
#             copying numpy/doc/byteswapping.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/doc
#             copying numpy/doc/structured_arrays.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/doc
#             copying numpy/doc/glossary.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/doc
#             creating build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             copying numpy/f2py/cfuncs.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             copying numpy/f2py/common_rules.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             copying numpy/f2py/crackfortran.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             copying numpy/f2py/cb_rules.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             copying numpy/f2py/__init__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             copying numpy/f2py/rules.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             copying numpy/f2py/f2py2e.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             copying numpy/f2py/func2subr.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             copying numpy/f2py/__version__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             copying numpy/f2py/diagnose.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             copying numpy/f2py/setup.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             copying numpy/f2py/capi_maps.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             copying numpy/f2py/f90mod_rules.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             copying numpy/f2py/f2py_testing.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             copying numpy/f2py/use_rules.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             copying numpy/f2py/info.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             copying numpy/f2py/auxfuncs.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             copying numpy/f2py/__main__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/f2py
#             creating build/lib.macosx-12.3-arm64-cpython-310/numpy/fft
#             copying numpy/fft/__init__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/fft
#             copying numpy/fft/setup.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/fft
#             copying numpy/fft/helper.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/fft
#             copying numpy/fft/fftpack.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/fft
#             copying numpy/fft/info.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/fft
#             creating build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/_iotools.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/mixins.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/nanfunctions.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/recfunctions.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/scimath.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/_version.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/user_array.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/__init__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/format.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/twodim_base.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/financial.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/index_tricks.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/npyio.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/shape_base.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/setup.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/stride_tricks.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/utils.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/arrayterator.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/function_base.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/arraysetops.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/arraypad.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/type_check.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/info.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/polynomial.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/_datasource.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             copying numpy/lib/ufunclike.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/lib
#             creating build/lib.macosx-12.3-arm64-cpython-310/numpy/linalg
#             copying numpy/linalg/__init__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/linalg
#             copying numpy/linalg/setup.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/linalg
#             copying numpy/linalg/linalg.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/linalg
#             copying numpy/linalg/info.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/linalg
#             creating build/lib.macosx-12.3-arm64-cpython-310/numpy/ma
#             copying numpy/ma/extras.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/ma
#             copying numpy/ma/version.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/ma
#             copying numpy/ma/testutils.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/ma
#             copying numpy/ma/__init__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/ma
#             copying numpy/ma/core.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/ma
#             copying numpy/ma/bench.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/ma
#             copying numpy/ma/setup.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/ma
#             copying numpy/ma/timer_comparison.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/ma
#             copying numpy/ma/mrecords.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/ma
#             creating build/lib.macosx-12.3-arm64-cpython-310/numpy/matrixlib
#             copying numpy/matrixlib/__init__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/matrixlib
#             copying numpy/matrixlib/setup.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/matrixlib
#             copying numpy/matrixlib/defmatrix.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/matrixlib
#             creating build/lib.macosx-12.3-arm64-cpython-310/numpy/polynomial
#             copying numpy/polynomial/laguerre.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/polynomial
#             copying numpy/polynomial/_polybase.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/polynomial
#             copying numpy/polynomial/polyutils.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/polynomial
#             copying numpy/polynomial/__init__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/polynomial
#             copying numpy/polynomial/setup.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/polynomial
#             copying numpy/polynomial/hermite_e.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/polynomial
#             copying numpy/polynomial/chebyshev.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/polynomial
#             copying numpy/polynomial/polynomial.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/polynomial
#             copying numpy/polynomial/legendre.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/polynomial
#             copying numpy/polynomial/hermite.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/polynomial
#             creating build/lib.macosx-12.3-arm64-cpython-310/numpy/random
#             copying numpy/random/__init__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/random
#             copying numpy/random/setup.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/random
#             copying numpy/random/info.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/random
#             creating build/lib.macosx-12.3-arm64-cpython-310/numpy/testing
#             copying numpy/testing/nosetester.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/testing
#             copying numpy/testing/__init__.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/testing
#             copying numpy/testing/noseclasses.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/testing
#             copying numpy/testing/setup.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/testing
#             copying numpy/testing/utils.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/testing
#             copying numpy/testing/print_coercion_tables.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/testing
#             copying numpy/testing/decorators.py -> build/lib.macosx-12.3-arm64-cpython-310/numpy/testing
#             running build_clib
#             customize UnixCCompiler
#             customize UnixCCompiler using build_clib
#             building 'npymath' library
#             compiling C sources
#             C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include
#
#             creating build/temp.macosx-12.3-arm64-cpython-310
#             creating build/temp.macosx-12.3-arm64-cpython-310/numpy
#             creating build/temp.macosx-12.3-arm64-cpython-310/numpy/core
#             creating build/temp.macosx-12.3-arm64-cpython-310/numpy/core/src
#             creating build/temp.macosx-12.3-arm64-cpython-310/numpy/core/src/npymath
#             creating build/temp.macosx-12.3-arm64-cpython-310/build
#             creating build/temp.macosx-12.3-arm64-cpython-310/build/src.macosx-12.3-arm64-3.1
#             creating build/temp.macosx-12.3-arm64-cpython-310/build/src.macosx-12.3-arm64-3.1/numpy
#             creating build/temp.macosx-12.3-arm64-cpython-310/build/src.macosx-12.3-arm64-3.1/numpy/core
#             creating build/temp.macosx-12.3-arm64-cpython-310/build/src.macosx-12.3-arm64-3.1/numpy/core/src
#             creating build/temp.macosx-12.3-arm64-cpython-310/build/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath
#             compile options: '-Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath -Inumpy/core/include -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy -Inumpy/core/src/private -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/ashu/.pyenv/versions/3.10.2/include/python3.10 -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/private -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/private -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/private -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath -c'
#             clang: numpy/core/src/npymath/npy_math.c
#             In file included from numpy/core/src/npymath/npy_math.c:9:
#             numpy/core/src/npymath/npy_math_internal.h.src:490:21: warning: incompatible pointer types passing 'npy_longdouble *' (aka 'double *') to parameter of type 'long double *' [-Wincompatible-pointer-types]
#                 return modfl(x, iptr);
#                                 ^~~~
#             /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/math.h:394:52: note: passing argument to parameter here
#             extern long double modfl(long double, long double *);
#                                                                ^
#             1 warning generated.
#             clang: build/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath/ieee754.c
#             clang: build/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath/npy_math_complex.c
#             numpy/core/src/npymath/npy_math_complex.c.src:61:25: warning: unused variable 'c_halff' [-Wunused-const-variable]
#             static const npy_cfloat c_halff = {0.5F, 0.0};
#                                     ^
#             numpy/core/src/npymath/npy_math_complex.c.src:62:25: warning: unused variable 'c_if' [-Wunused-const-variable]
#             static const npy_cfloat c_if = {0.0, 1.0F};
#                                     ^
#             numpy/core/src/npymath/npy_math_complex.c.src:63:25: warning: unused variable 'c_ihalff' [-Wunused-const-variable]
#             static const npy_cfloat c_ihalff = {0.0, 0.5F};
#                                     ^
#             numpy/core/src/npymath/npy_math_complex.c.src:73:1: warning: unused function 'caddf' [-Wunused-function]
#             caddf(npy_cfloat a, npy_cfloat b)
#             ^
#             numpy/core/src/npymath/npy_math_complex.c.src:81:1: warning: unused function 'csubf' [-Wunused-function]
#             csubf(npy_cfloat a, npy_cfloat b)
#             ^
#             numpy/core/src/npymath/npy_math_complex.c.src:131:1: warning: unused function 'cnegf' [-Wunused-function]
#             cnegf(npy_cfloat a)
#             ^
#             numpy/core/src/npymath/npy_math_complex.c.src:138:1: warning: unused function 'cmulif' [-Wunused-function]
#             cmulif(npy_cfloat a)
#             ^
#             numpy/core/src/npymath/npy_math_complex.c.src:61:26: warning: unused variable 'c_half' [-Wunused-const-variable]
#             static const npy_cdouble c_half = {0.5, 0.0};
#                                      ^
#             numpy/core/src/npymath/npy_math_complex.c.src:62:26: warning: unused variable 'c_i' [-Wunused-const-variable]
#             static const npy_cdouble c_i = {0.0, 1.0};
#                                      ^
#             numpy/core/src/npymath/npy_math_complex.c.src:63:26: warning: unused variable 'c_ihalf' [-Wunused-const-variable]
#             static const npy_cdouble c_ihalf = {0.0, 0.5};
#                                      ^
#             numpy/core/src/npymath/npy_math_complex.c.src:73:1: warning: unused function 'cadd' [-Wunused-function]
#             cadd(npy_cdouble a, npy_cdouble b)
#             ^
#             numpy/core/src/npymath/npy_math_complex.c.src:81:1: warning: unused function 'csub' [-Wunused-function]
#             csub(npy_cdouble a, npy_cdouble b)
#             ^
#             numpy/core/src/npymath/npy_math_complex.c.src:131:1: warning: unused function 'cneg' [-Wunused-function]
#             cneg(npy_cdouble a)
#             ^
#             numpy/core/src/npymath/npy_math_complex.c.src:138:1: warning: unused function 'cmuli' [-Wunused-function]
#             cmuli(npy_cdouble a)
#             ^
#             numpy/core/src/npymath/npy_math_complex.c.src:61:30: warning: unused variable 'c_halfl' [-Wunused-const-variable]
#             static const npy_clongdouble c_halfl = {0.5L, 0.0};
#                                          ^
#             numpy/core/src/npymath/npy_math_complex.c.src:62:30: warning: unused variable 'c_il' [-Wunused-const-variable]
#             static const npy_clongdouble c_il = {0.0, 1.0L};
#                                          ^
#             numpy/core/src/npymath/npy_math_complex.c.src:63:30: warning: unused variable 'c_ihalfl' [-Wunused-const-variable]
#             static const npy_clongdouble c_ihalfl = {0.0, 0.5L};
#                                          ^
#             numpy/core/src/npymath/npy_math_complex.c.src:73:1: warning: unused function 'caddl' [-Wunused-function]
#             caddl(npy_clongdouble a, npy_clongdouble b)
#             ^
#             numpy/core/src/npymath/npy_math_complex.c.src:81:1: warning: unused function 'csubl' [-Wunused-function]
#             csubl(npy_clongdouble a, npy_clongdouble b)
#             ^
#             numpy/core/src/npymath/npy_math_complex.c.src:131:1: warning: unused function 'cnegl' [-Wunused-function]
#             cnegl(npy_clongdouble a)
#             ^
#             numpy/core/src/npymath/npy_math_complex.c.src:138:1: warning: unused function 'cmulil' [-Wunused-function]
#             cmulil(npy_clongdouble a)
#             ^
#             21 warnings generated.
#             clang: numpy/core/src/npymath/halffloat.c
#             ar: adding 4 object files to build/temp.macosx-12.3-arm64-cpython-310/libnpymath.a
#             ranlib:@ build/temp.macosx-12.3-arm64-cpython-310/libnpymath.a
#             building 'npysort' library
#             compiling C sources
#             C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include
#
#             creating build/temp.macosx-12.3-arm64-cpython-310/build/src.macosx-12.3-arm64-3.1/numpy/core/src/npysort
#             compile options: '-Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/private -Inumpy/core/include -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy -Inumpy/core/src/private -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/ashu/.pyenv/versions/3.10.2/include/python3.10 -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/private -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/private -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/private -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath -c'
#             clang: build/src.macosx-12.3-arm64-3.1/numpy/core/src/npysort/quicksort.c
# ...
#                          ^
#                          /* DISABLES CODE */ ( )
#             numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#                     npy_intp k;
#                     ^~~~~~~~~~~
#             numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#                 else if (0 && kth == num - 1) {
#                          ^
#                          /* DISABLES CODE */ ( )
#             numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#                     npy_intp k;
#                     ^~~~~~~~~~~
#             numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#                 else if (0 && kth == num - 1) {
#                          ^
#                          /* DISABLES CODE */ ( )
#             numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#                     npy_intp k;
#                     ^~~~~~~~~~~
#             numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#                 else if (0 && kth == num - 1) {
#                          ^
#                          /* DISABLES CODE */ ( )
#             numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#                     npy_intp k;
#                     ^~~~~~~~~~~
#             numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#                 else if (0 && kth == num - 1) {
#                          ^
#                          /* DISABLES CODE */ ( )
#             numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#                     npy_intp k;
#                     ^~~~~~~~~~~
#             numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#                 else if (0 && kth == num - 1) {
#                          ^
#                          /* DISABLES CODE */ ( )
#             numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#                     npy_intp k;
#                     ^~~~~~~~~~~
#             numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#                 else if (0 && kth == num - 1) {
#                          ^
#                          /* DISABLES CODE */ ( )
#             numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#                     npy_intp k;
#                     ^~~~~~~~~~~
#             numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#                 else if (0 && kth == num - 1) {
#                          ^
#                          /* DISABLES CODE */ ( )
#             numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#                     npy_intp k;
#                     ^~~~~~~~~~~
#             numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#                 else if (0 && kth == num - 1) {
#                          ^
#                          /* DISABLES CODE */ ( )
#             numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#                     npy_intp k;
#                     ^~~~~~~~~~~
#             numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#                 else if (0 && kth == num - 1) {
#                          ^
#                          /* DISABLES CODE */ ( )
#             numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#                     npy_intp k;
#                     ^~~~~~~~~~~
#             numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#                 else if (0 && kth == num - 1) {
#                          ^
#                          /* DISABLES CODE */ ( )
#             numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#                     npy_intp k;
#                     ^~~~~~~~~~~
#             numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#                 else if (0 && kth == num - 1) {
#                          ^
#                          /* DISABLES CODE */ ( )
#             numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#                     npy_intp k;
#                     ^~~~~~~~~~~
#             numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#                 else if (0 && kth == num - 1) {
#                          ^
#                          /* DISABLES CODE */ ( )
#             numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#                     npy_intp k;
#                     ^~~~~~~~~~~
#             numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#                 else if (0 && kth == num - 1) {
#                          ^
#                          /* DISABLES CODE */ ( )
#             numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#                     npy_intp k;
#                     ^~~~~~~~~~~
#             numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#                 else if (0 && kth == num - 1) {
#                          ^
#                          /* DISABLES CODE */ ( )
#             numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#                     npy_intp k;
#                     ^~~~~~~~~~~
#             numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#                 else if (0 && kth == num - 1) {
#                          ^
#                          /* DISABLES CODE */ ( )
#             numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#                     npy_intp k;
#                     ^~~~~~~~~~~
#             numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#                 else if (0 && kth == num - 1) {
#                          ^
#                          /* DISABLES CODE */ ( )
#             26 warnings generated.
#             clang: build/src.macosx-12.3-arm64-3.1/numpy/core/src/npysort/binsearch.c
#             In file included from numpy/core/src/npysort/binsearch.c.src:6:
#             numpy/core/src/private/npy_binsearch.h.src:120:45: warning: comparison of integers of different signs: 'enum NPY_TYPES' and 'int' [-Wsign-compare]
#                     if (_binsearch_map[mid_idx].typenum < type) {
#                         ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ^ ~~~~
#             numpy/core/src/private/npy_binsearch.h.src:128:64: warning: comparison of integers of different signs: 'enum NPY_TYPES' and 'int' [-Wsign-compare]
#                 if (min_idx < num_funcs && _binsearch_map[min_idx].typenum == type) {
#                                            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ^  ~~~~
#             numpy/core/src/private/npy_binsearch.h.src:120:48: warning: comparison of integers of different signs: 'enum NPY_TYPES' and 'int' [-Wsign-compare]
#                     if (_argbinsearch_map[mid_idx].typenum < type) {
#                         ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ^ ~~~~
#             numpy/core/src/private/npy_binsearch.h.src:128:67: warning: comparison of integers of different signs: 'enum NPY_TYPES' and 'int' [-Wsign-compare]
#                 if (min_idx < num_funcs && _argbinsearch_map[min_idx].typenum == type) {
#                                            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ^  ~~~~
#             4 warnings generated.
#             ar: adding 5 object files to build/temp.macosx-12.3-arm64-cpython-310/libnpysort.a
#             ranlib:@ build/temp.macosx-12.3-arm64-cpython-310/libnpysort.a
#             running build_ext
#             customize UnixCCompiler
#             customize UnixCCompiler using build_ext
#             building 'numpy.core._dummy' extension
#             compiling C sources
#             C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include
#
#             compile options: '-DNPY_INTERNAL_BUILD=1 -DHAVE_NPY_CONFIG_H=1 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -Inumpy/core/include -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy -Inumpy/core/src/private -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/ashu/.pyenv/versions/3.10.2/include/python3.10 -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/private -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/private -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/private -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath -c'
#             clang: numpy/core/src/dummymodule.c
#             clang -bundle -undefined dynamic_lookup -L/opt/homebrew/opt/readline/lib -L/opt/homebrew/opt/readline/lib -L/Users/ashu/.pyenv/versions/3.10.2/lib -L/opt/homebrew/lib -L/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/lib -L/opt/homebrew/opt/readline/lib -L/opt/homebrew/opt/readline/lib -L/Users/ashu/.pyenv/versions/3.10.2/lib -L/opt/homebrew/lib -L/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/lib build/temp.macosx-12.3-arm64-cpython-310/numpy/core/src/dummymodule.o -Lbuild/temp.macosx-12.3-arm64-cpython-310 -o build/lib.macosx-12.3-arm64-cpython-310/numpy/core/_dummy.cpython-310-darwin.so
#             building 'numpy.core.multiarray' extension
#             compiling C sources
#             C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include
#
#             creating build/temp.macosx-12.3-arm64-cpython-310/numpy/core/src/multiarray
#             creating build/temp.macosx-12.3-arm64-cpython-310/build/src.macosx-12.3-arm64-3.1/numpy/core/src/multiarray
#             creating build/temp.macosx-12.3-arm64-cpython-310/numpy/core/src/private
#             creating build/temp.macosx-12.3-arm64-cpython-310/private
#             creating build/temp.macosx-12.3-arm64-cpython-310/private/var
#             creating build/temp.macosx-12.3-arm64-cpython-310/private/var/folders
#             creating build/temp.macosx-12.3-arm64-cpython-310/private/var/folders/y4
#             creating build/temp.macosx-12.3-arm64-cpython-310/private/var/folders/y4/6zfff_pj0h39ylj3s39306rc0000gn
#             creating build/temp.macosx-12.3-arm64-cpython-310/private/var/folders/y4/6zfff_pj0h39ylj3s39306rc0000gn/T
#             creating build/temp.macosx-12.3-arm64-cpython-310/private/var/folders/y4/6zfff_pj0h39ylj3s39306rc0000gn/T/pip-install-3s8nr27m
#             creating build/temp.macosx-12.3-arm64-cpython-310/private/var/folders/y4/6zfff_pj0h39ylj3s39306rc0000gn/T/pip-install-3s8nr27m/numpy_e4b27de44edc4e4cb031f20fe50c7e3d
#             creating build/temp.macosx-12.3-arm64-cpython-310/private/var/folders/y4/6zfff_pj0h39ylj3s39306rc0000gn/T/pip-install-3s8nr27m/numpy_e4b27de44edc4e4cb031f20fe50c7e3d/numpy
#             creating build/temp.macosx-12.3-arm64-cpython-310/private/var/folders/y4/6zfff_pj0h39ylj3s39306rc0000gn/T/pip-install-3s8nr27m/numpy_e4b27de44edc4e4cb031f20fe50c7e3d/numpy/_build_utils
#             creating build/temp.macosx-12.3-arm64-cpython-310/private/var/folders/y4/6zfff_pj0h39ylj3s39306rc0000gn/T/pip-install-3s8nr27m/numpy_e4b27de44edc4e4cb031f20fe50c7e3d/numpy/_build_utils/src
#             compile options: '-DNPY_INTERNAL_BUILD=1 -DHAVE_NPY_CONFIG_H=1 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DNO_ATLAS_INFO=3 -DHAVE_CBLAS -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/private -Inumpy/core/include -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy -Inumpy/core/src/private -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/ashu/.pyenv/versions/3.10.2/include/python3.10 -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/private -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/private -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/private -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath -c'
#             extra options: '-faltivec -I/System/Library/Frameworks/vecLib.framework/Headers'
#             clang: numpy/core/src/multiarray/alloc.c
#             clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#             clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#             error: Command "clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include -DNPY_INTERNAL_BUILD=1 -DHAVE_NPY_CONFIG_H=1 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DNO_ATLAS_INFO=3 -DHAVE_CBLAS -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/private -Inumpy/core/include -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/include/numpy -Inumpy/core/src/private -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/ashu/.pyenv/versions/3.10.2/include/python3.10 -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/private -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/private -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/private -Ibuild/src.macosx-12.3-arm64-3.1/numpy/core/src/npymath -c numpy/core/src/multiarray/alloc.c -o build/temp.macosx-12.3-arm64-cpython-310/numpy/core/src/multiarray/alloc.o -MMD -MF build/temp.macosx-12.3-arm64-cpython-310/numpy/core/src/multiarray/alloc.o.d -faltivec -I/System/Library/Frameworks/vecLib.framework/Headers" failed with exit status 1
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#         ERROR: Failed building wheel for numpy
#       Failed to build numpy
#       ERROR: Could not build wheels for numpy, which is required to install pyproject.toml-based projects
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Note: you may need to restart the kernel to use updated packages.
